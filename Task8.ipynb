# %%
#! /usr/bin/python3

print("content-type: text/html")
print()


print('''<style>
pre{
color: black;
font-weight: bold;
font-size: 20px;
}
</style>''')


import cgi
import subprocess as sb

fs = cgi.FieldStorage()

plate_no = fs.getvalue("x")


if plate_no == "KA05NB1786":
    print("<body style='padding: 40px;'>")
    print('<h1 style="color:red;" >Output</h1>')
    print('''<pre>
    Registration Name : RADHESHYAM PANCHARIYA
    License No : 12345678910
    Make / Model : KIA / SELTOS
    Registration Date : 16/5/2019
    Registering Authority : DELHI , INDIA
    Fuel Type : PETROL
    Engine No : IVK3N1734538
    Chassis No : HMSURVWVQSVWE
    Insurance Upto : 5/13/2022
    Fitness Upto : 4/8/2030
    </pre>''')
    print("</body>")

elif plate_no == "TN8zB6264":
    print("<body style='padding: 40px;'>")
    print('<h1 style="color:red;" >Output</h1>')
    print('''<pre>
    Registration Name : PIYUSH PANCHARIYA
    License No : 10987654321
    Make / Model : HYUNDAI / CRETA
    Registration Date : 2/3/2020
    Registering Authority : WEST BANGOL, INDIA
    Fuel Type : PETROL
    Engine No : IVK3N1734538
    Chassis No : HMSURVWVQSVWE
    Insurance Upto : 5/13/2022
    </pre>''')
    print("</body>")


else:
    print("<body style='padding: 40px;'>")
    print('<h1 style="color:#df405a;" >Output</h1>')
    print("No data available for this number...")
    print("</body>")
